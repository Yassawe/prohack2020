# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
Y=pd.read_csv('Y.csv').iloc[:,1:]
X=pd.read_csv('X.csv').iloc[:,1:]

print(X.shape)
print(Y.shape)
# Out:
# (890, 77)
# (890, 1)

# %%
Y.head()
# Out:
#           y
# 0  0.033038
# 1  0.041447
# 2  0.036504
# 3  0.036264
# 4  0.041198

# %%
X.head()
# Out:
#    existence expectancy index  existence expectancy at birth  \
# 0                    0.456086                      51.562543
# 1                    0.529835                      57.228262
# 2                    0.560976                      59.379539
# 3                    0.565910                      59.952390
# 4                    0.588274                      55.428320
#
#    Gross income per capita  Income Index  \
# 0             12236.576447      0.593325
# 1              3431.883825      0.675407
# 2             27562.914252      0.594624
# 3             20352.232905      0.837700
# 4             23959.704016      0.520579
#
#    Expected years of education (galactic years)  \
# 0                                     10.414164
# 1                                      7.239485
# 2                                     11.774890
# 3                                     11.613621
# 4                                     10.392416
#
#    Mean years of education (galactic years)  \
# ...

# %%
index = X.index

pfi2 = np.square(-np.log(Y['y']+0.01)+3)

# %%
d = pd.DataFrame({
    'index':index,
    'pred': Y['y'],
    'opt_pred':0,
    'pfi^2':pfi2,
    'eei':X['existence expectancy index']
})

# %%
d_sort_p=d.sort_values(by=['pfi^2'], ascending=False)

# %%
d_sort_p.head()
# Out:
#      index      pred  opt_pred      pfi^2       eei
# 39      39  0.015600         0  44.424306  0.659167
# 44      44  0.015717         0  44.363772  0.661723
# 202    202  0.015906         0  44.266125  0.817197
# 117    117  0.016419         0  44.005411  0.763177
# 138    138  0.016430         0  44.000323  0.775467

# %%
d_sort_p.iloc[0:500].opt_pred = 100
# Out:
# C:\Users\Yassawe\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
d_sort_i=d_sort_p.sort_values(by=['index'], ascending=True)

# %%
d_sort_i.head()
# Out:
#    index      pred  opt_pred      pfi^2       eei
# 0      0  0.033038       100  37.769319  0.456086
# 1      1  0.041447         0  35.607399  0.529835
# 2      2  0.036504       100  36.823210  0.560976
# 3      3  0.036264       100  36.886033  0.565910
# 4      4  0.041198       100  35.665407  0.588274

# %%
resources_for_poor=d_sort_i.loc[d_sort_i.eei < 0.7, 'opt_pred'].sum()
all_resources=d_sort_i['opt_pred'].sum()

# %%
d_sort_i[['index', 'pred', 'opt_pred']].to_csv('SUBMISSION.csv', index=False)
